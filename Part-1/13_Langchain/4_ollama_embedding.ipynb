# %%
from langchain_community.embeddings import OllamaEmbeddings

# %%
embedding=OllamaEmbeddings(
    model="phi4:latest"
)

# %%
r1=embedding.embed_documents(["Alpha is the first character of Greek alphabet."])

# %%
r1=embedding.aembed_query("Who are you?")

# %%
r1
# Out:
# <coroutine object Embeddings.aembed_query at 0x7f1959e0e0a0>

# %%
r1=embedding.embed_query(["""Cost/Reveneu ItemAmount: Factory rent (90000 USD), Components and materials (60000 USD), Salaries of administrative staff (150000 USD), packaging and shipping (12000 USD), direct labor(36000 USD), marketing and advertising campaigns(50000 USD),sales commission(8000 USD),equipment dereciation(20000 USD),selling price(200000 USD). calculate total fixed cost,total variable cost per unit and selling price per unit if total production is 1000 units.
calculate bep(units),bep(sales),target sales when target profit 120000"""])

# %%
type(r1)
# Out:
# list

# %%
r1
# Out:
# [1.1907230615615845,
#  3.7470552921295166,
#  0.7703445553779602,
#  0.9995042681694031,
#  -2.1803345680236816,
#  -1.138182520866394,
#  1.444358229637146,
#  -0.03267703950405121,
#  -1.706473469734192,
#  -1.25161612033844,
#  -2.1721692085266113,
#  -2.2444369792938232,
#  2.538412570953369,
#  -2.418062448501587,
#  -2.2279272079467773,
#  -1.9761356115341187,
#  1.1988725662231445,
#  1.4754306077957153,
#  -1.2035976648330688,
#  0.44973644614219666,
#  1.143268346786499,
#  1.2981926202774048,
#  2.6451237201690674,
#  0.6087143421173096,
#  0.3388456404209137,
#  -2.40386962890625,
#  -2.0996766090393066,
#  1.0782073736190796,
#  -1.765927791595459,
#  1.2701197862625122,
#  -2.637331008911133,
#  0.6833515763282776,
#  -0.917569100856781,
#  3.022020101547241,
#  2.2568182945251465,
#  0.7631099224090576,
#  -0.586838960647583,
#  1.9968409538269043,
#  1.6227095127105713,
#  0.9555466175079346,
#  1.9793823957443237,
#  -1.1250252723693848,
#  3.2494213581085205,
# ...
