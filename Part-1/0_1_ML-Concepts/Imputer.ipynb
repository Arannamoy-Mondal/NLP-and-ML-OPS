# %%
from sklearn.impute import SimpleImputer

# %%
imputer_mode=SimpleImputer(strategy="mode")
imputer_median=SimpleImputer(strategy="median")

# %%
print(type(imputer_median))
# Out:
# <class 'sklearn.impute._base.SimpleImputer'>

# %%
import pandas as pd
df=pd.read_csv("../Sample_Data/CPU Testing Data - Sheet1.csv")

# %%
df
# Out:
#              model              CPU Name  total duration(m.s)  \
# 0       grmma3:27b  ryzen 9 3950x 3.5GHz             5.500000
# 1         phi4:14b  ryzen 9 3950x 3.5GHz             2.132954
# 2     qwen3-vl:32b  ryzen 9 3950x 3.5GHz            29.156016
# 3         phi4:14b         i5 12400 4GHz             2.276646
# 4       grmma3:27b         i5 12400 4GHz             6.438154
# 5   deepseek-r1:8b  ryzen 9 3950x 3.5GHz            14.570000
# 6  deepseek-r1:32b  ryzen 9 3950x 3.5GHz                  NaN
# 7              NaN                   NaN                  NaN
# 8              NaN                   NaN                  NaN
# 9              NaN                   NaN                  NaN
#
#    load duration(ms)  prompt eval count(token)  prompt eval duration(s)  \
# 0         325.000000                     155.0                 3.570000
# 1          84.785767                     129.0                 1.004515
# 2         148.483672                     163.0                 1.731210
# 3          60.641578                     131.0                 0.819710
# 4         369.423658                     165.0                14.350343
# 5         119.840000                     159.0               111.960000
# 6                NaN                       NaN                      NaN
# 7                NaN                       NaN                      NaN
# 8                NaN                       NaN                      NaN
# 9                NaN                       NaN                      NaN
#
#    prompt eval rate(token/s)  eval count(tokens) eval duration(m.s)  \
# 0                      43.31               956.0               5.45
# 1                     128.42               843.0        2.113064349
# 2                      94.15              4559.0        29.11409097
# 3                     159.81               820.0      2.1430929244s
# 4                      11.50               931.0        6.284872064
# 5                    1420.14             40960.0               13.5
# 6                        NaN                 NaN                NaN
# 7                        NaN                 NaN                NaN
# 8                        NaN                 NaN                NaN
# 9                        NaN                 NaN                NaN
#
#    eval rate(token/s) gpu enable  \
# 0                2.77         no
# 1                6.42         no
# 2                2.60         no
# 3                6.75         no
# 4                2.40         no
# 5               49.32         no
# 6                 NaN        yes
# 7                 NaN        NaN
# 8                 NaN        NaN
# 9                 NaN        NaN
#
#                                               prompt     Remark
# 0  Cost/Reveneu ItemAmount: Factory rent (90000 U...    correct
# 1  Cost/Reveneu ItemAmount: Factory rent (90000 U...    correct
# 2  Cost/Reveneu ItemAmount: Factory rent (90000 U...    correct
# 3  Cost/Reveneu ItemAmount: Factory rent (90000 U...    correct
# 4  Cost/Reveneu ItemAmount: Factory rent (90000 U...    correct
# 5  Cost/Reveneu ItemAmount: Factory rent (90000 U...  incorrect
# 6  Cost/Reveneu ItemAmount: Factory rent (90000 U...    correct
# 7  Cost/Reveneu ItemAmount: Factory rent (90000 U...    correct
# 8                                                NaN    correct
# 9                                                NaN    correct

# %%
import subprocess

# %%
subprocess.run(["df","-h"])
# Out:
# Filesystem                         Size  Used Avail Use% Mounted on
# tmpfs                              3.2G  3.5M  3.2G   1% /run
# /dev/mapper/ubuntu--vg-ubuntu--lv  466G  175G  267G  40% /
# tmpfs                               16G  3.1M   16G   1% /dev/shm
# tmpfs                              5.0M     0  5.0M   0% /run/lock
# /dev/nvme0n1p2                     2.0G  250M  1.6G  14% /boot
# /dev/nvme0n1p1                     1.1G  6.1M  1.1G   1% /boot/efi
# tmpfs                              3.2G   24K  3.2G   1% /run/user/1000
# CompletedProcess(args=['df', '-h'], returncode=0)
