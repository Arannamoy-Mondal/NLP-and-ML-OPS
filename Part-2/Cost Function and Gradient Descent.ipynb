# %% [markdown]
# #### MSE -> Mean Squared Error (Cost Function)
# - J(m,c)=(y_i - y_j)^2/n

# %% [markdown]
# #### Visualizing Cost Function

# %% [markdown]
# #### Gradient Decent

# %%
import numpy as np 
import pandas as pd
from sklearn.linear_model import LinearRegression,SGDRegressor
from sklearn.metrics import mean_squared_error

# %%
hours=np.arange(2,12,2).reshape(-1,1)
marks=np.arange(88,100,2)
display(hours)
display(marks)
# Out:
# array([[ 2],
#        [ 4],
#        [ 6],
#        [ 8],
#        [10]])
# array([88, 90, 92, 94, 96, 98])
