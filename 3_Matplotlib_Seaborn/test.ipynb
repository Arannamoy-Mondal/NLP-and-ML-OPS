# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import yfinance as yf

# %%
hours=[2,3,4,1,5,7,3]
days=np.arange(1,8)

# %%
plt.xlabel("Days")
plt.ylabel("Study Hours")
plt.title("Days vs Study Hours")
plt.plot(days,hours)

# %%
btc=pd.read_csv("../archive/BTC.csv")
btc=btc[::365]

# %%
plt.scatter(np.array(btc['date']),np.array(btc['high']))

# %%
btc
