# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
df=pd.read_csv("../archive/BTC.csv")
df1=df.loc[:,['high','date']]

# %%
sns.lineplot(df)
# Out:
# <Axes: >

# %%
sns.relplot(df)

# %%
sns.relplot(kind="line",data=df,x='date',y='high')

# %%
sns.scatterplot(data=df,x='high',y='date')
# Out:
# <Axes: xlabel='high', ylabel='date'>
