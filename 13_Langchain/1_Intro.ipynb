# %% [markdown]
# #### What will we do
# - 1. Get setup with Langchain, LangSmith and LangServe
# - 2. Build application with langchain
# - 3. trace application with langsmith
# - 4. serve application with langserve
