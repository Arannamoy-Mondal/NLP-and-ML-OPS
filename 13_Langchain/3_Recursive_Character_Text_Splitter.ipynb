# %%
from langchain_community.document_loaders import PyPDFLoader
data=PyPDFLoader("output.pdf").load()
data
# Out:
# [Document(metadata={'producer': 'cairo 1.18.4 (https://cairographics.org)', 'creator': 'PyPDF', 'creationdate': '2025-11-14T03:53:17+06:00', 'source': 'output.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='File: amortization_problem1.csv\nPage 1 of 1\nYear,Payment,Interest,Principal,Ending Balance\n1,125228.23,40000.0,85228.23,414771.77\n2,125228.23,33181.74,92046.49,322725.29\n3,125228.23,25818.02,99410.2,223315.08\n4,125228.23,17865.21,107363.02,115952.06\n5,125228.23,9276.16,115952.06,0.0')]

# %% [markdown]
# ### How to recursively split text by characters

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

# %%
text_splitter=RecursiveCharacterTextSplitter(chunk_size=500,chunk_overlap=50)

# %%
final_documents=text_splitter.split_documents(data)

# %%
print(final_documents[0])
# Out:
# page_content='File: amortization_problem1.csv
# Page 1 of 1
# Year,Payment,Interest,Principal,Ending Balance
# 1,125228.23,40000.0,85228.23,414771.77
# 2,125228.23,33181.74,92046.49,322725.29
# 3,125228.23,25818.02,99410.2,223315.08
# 4,125228.23,17865.21,107363.02,115952.06
# 5,125228.23,9276.16,115952.06,0.0' metadata={'producer': 'cairo 1.18.4 (https://cairographics.org)', 'creator': 'PyPDF', 'creationdate': '2025-11-14T03:53:17+06:00', 'source': 'output.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}
