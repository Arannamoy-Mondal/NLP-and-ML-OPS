# %%
import pandas as pd
df=pd.read_csv("./Sample_Data/Daily_ETH_USD_2010_2025.csv")
df.to_excel("./Sample_Data/Daily_ETH_USD_2010_2025.xlsx")
df.to_json("./Sample_Data/Daily_ETH_USD_2010_2025.json")

# %%
import os
files=os.listdir("Sample_Data")
print(files)

for file in files:
    name=file.split(".")
    df=pd.read_csv(f"./Sample_Data/{name[0]}.csv")
    df.to_excel(f"./Sample_Data/{name[0]}.xlsx")
    df.to_json(f"./Sample_Data/{name[0]}.json")
    print(name)
# Out:
# ['Daily_BTC_USD_2010_2025.csv', 'Daily_EUR_USD_2010_2025.csv', 'Daily_BTC_USD_2010_2025.json', 'Daily_NVDA_2010_2025.csv', 'Daily_ETH_USD_2010_2025.json', 'Daily_BTC_USD_2010_2025.xlsx', 'Daily_MSFT_2010_2025.csv', 'Daily_GOOG_2010_2025.csv', 'Daily_JPY_USD_2010_2025.csv', 'Daily_ETH_USD_2010_2025.csv', 'Daily_SOL_USD_2010_2025.csv', 'Daily_GBP_USD_2010_2025.csv', 'Daily_XAU_USD_2010_2025.csv', 'Daily_ETH_USD_2010_2025.xlsx']
# ['Daily_BTC_USD_2010_2025', 'csv']
# ['Daily_EUR_USD_2010_2025', 'csv']
# ['Daily_BTC_USD_2010_2025', 'json']
# ['Daily_NVDA_2010_2025', 'csv']
# ['Daily_ETH_USD_2010_2025', 'json']
# ['Daily_BTC_USD_2010_2025', 'xlsx']
# ['Daily_MSFT_2010_2025', 'csv']
# ['Daily_GOOG_2010_2025', 'csv']
# ['Daily_JPY_USD_2010_2025', 'csv']
# ['Daily_ETH_USD_2010_2025', 'csv']
# ['Daily_SOL_USD_2010_2025', 'csv']
# ['Daily_GBP_USD_2010_2025', 'csv']
# ['Daily_XAU_USD_2010_2025', 'csv']
# ['Daily_ETH_USD_2010_2025', 'xlsx']
